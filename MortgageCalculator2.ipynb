# %% [markdown]
# ## create variables

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
import ipywidgets

# %%
def get_values_from_key(list_of_dictionaries, key):
    """
    Extracts all values associated with a specific key from a list of dictionaries.

    Args:
        list_of_dictionaries: A list of dictionaries.
        key: The key to extract values for.

    Returns:
        A list containing all values associated with the given key.
    """
    return [dictionary[key] for dictionary in list_of_dictionaries if key in dictionary]

# %%
def calculate_amortization_schedule(loanAmt, interestRate, loanTerm):
    monthly_rate = annual_rate / 100 / 12
    total_payments = loan_term_years * 12

    # Calculate fixed monthly mortgage payment
    monthly_payment = loan_amount * monthly_rate / (1 - (1 + monthly_rate) ** -total_payments)

    schedule = []
    balance = loan_amount

    for month in range(1, total_payments + 1):
        interest = balance * monthly_rate
        principal = monthly_payment - interest
        balance -= principal

        schedule.append({
            "Month": month,
            "Payment": round(monthly_payment, 2),
            "Principal": round(principal, 2),
            "Interest": round(interest, 2),
            "Balance": round(balance if balance > 0 else 0, 2)
        })

    return schedule
def average_chunks(X, chunk_size=12):
    """
    Averages every `chunk_size` consecutive items in list X.

    :param X: List of numbers (length must be divisible by chunk_size)
    :param chunk_size: Number of items to average together
    :return: List of averaged values
    """
    if len(X) % chunk_size != 0:
        raise ValueError("List length must be divisible by chunk size.")

    return [
        sum(X[i:i + chunk_size]) / chunk_size
        for i in range(0, len(X), chunk_size)
    ]
def Sum_years(schedule_input,Var):
    V=get_values_from_key(schedule_input,Var)
    #interest=get_values_from_key(schedule_input,"Interest")
    #payment=get_values_from_key(schedule_input,"Payment")
    
    return average_chunks(V,chunk_size=12)
    chunk_Interest(interest,chunk_size=12)
    chunk_Payment(Payment,chunk_size=12)

# %%
# House Price
price=800000
# Down Payment
downPayment=200000
# Down payment percent
downPcnt=downPayment/price
# Loan Amount
loanAmt= price-downPayment
# Annual Interest Rate (percent%)
interestRate= 7.21
# Life of Loan (Years) aka: Loan term
loanTerm= 30
# Number of Payments per Year
nAnnualPayments= 12
# Interest Total Cost
interestCost=(interestRate/100)*loanAmt
# Monthly mortgage
#mortgageMonthly=(loanAmt+interestCost)/(loanTerm*nAnnualPayments)
#mortgageInterestYearly=interestCost/(loanTerm*nAnnualPayments)

# propTax (percent)
tax=price*(18.42/1000)
taxMonthly=tax/12
# Insurance (percent)
insurancePcnt= .04
#Monthly insurance
insuranceMonthly=(price*insurancePcnt)/12
# HOA (monthly)
HOA=360

# Yearly income
incomeAnnual=300000

# %%
# Annual house appreciation
pctAnnualGrowth=.05
years=[]
# total growth in dollars
#growth=pctAnnualGrowth*price*years
growth=[]

# %% [markdown]
# ## Make equation for buying

# %%
def calc_investment_growth(price, pctAnnualGrowth, y, compounds_per_year=1):
    """
    Calculates the future value of an investment using compound interest.

    :param price: Initial investment amount (P)
    :param pctAnnualGrowth: Annual interest rate (in percent, e.g. 5 for 5%)
    :param y: Number of years the money is invested (t)
    :param compounds_per_year: Number of times interest is compounded per year (n)
    :return: Future value of the investment (A)
    """
    growth = (price * (1 + pctAnnualGrowth / compounds_per_year) ** (compounds_per_year * y))-price
    return growth

# %%
def create_growthChart(n):
    yearList=range(n)
    growthChart = []
    for x in yearList:
        growthChart.append(round(calc_investment_growth(price, pctAnnualGrowth, x, compounds_per_year=1)))
    return growthChart

# %%
def calc_cost(y):
    cost=(mortgageMonthly+insuranceMonthly+taxMonthly+HOA)*12*y
    return cost

# %%
def create_costChart(n):
    yearList=range(n)
    costChart = []

    for x in yearList:
        costChart.append(round(calc_cost(x)))
    return costChart

# %%
def chart_costs(n):

    y1 = np.array(create_costChart(n))
    y2 = np.array(create_growthChart(n))

    plt.plot(y1,label="costs")
    plt.plot(y2,label="gains")
    plt.legend(loc="upper left")
    plt.ticklabel_format(axis='both', style='plain',)
    plt.show()

# %%
 chart_costs(20)

# %% [markdown]
# ## determine monthly mortgage

# %%
# Monthly cost Sum of Monthly Payments
monthlyTotal=mortgageMonthly+insuranceMonthly+taxMonthly+HOA
monthlyTotal
# Out:
# 6041.5

# %%
mortgageMonthly
insuranceMonthly
taxMonthly
# Out:
# 1228.0000000000002

# %%
totalSpent=(monthlyTotal*years*12)
totalGained=growth

# %%
growth-totalSpent
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[293], line 1
# ----> 1 growth-totalSpent
#
# TypeError: unsupported operand type(s) for -: 'list' and 'float'

# %%
def calculate_amortization_schedule(loan_amount, annual_rate, loan_term_years):
    """
    Calculates and returns the amortization schedule for a fixed-rate mortgage.
    
    :param loan_amount: Initial mortgage loan amount
    :param annual_rate: Annual interest rate (in percent)
    :param loan_term_years: Loan term in years
    :return: List of dicts representing the amortization schedule
    """
    monthly_rate = annual_rate / 100 / 12
    total_payments = loan_term_years * 12

    # Calculate fixed monthly mortgage payment
    monthly_payment = loan_amount * monthly_rate / (1 - (1 + monthly_rate) ** -total_payments)

    schedule = []
    balance = loan_amount

    for month in range(1, total_payments + 1):
        interest = balance * monthly_rate
        principal = monthly_payment - interest
        balance -= principal

        schedule.append({
            "Month": month,
            "Payment": round(monthly_payment, 2),
            "Principal": round(principal, 2),
            "Interest": round(interest, 2),
            "Balance": round(balance if balance > 0 else 0, 2)
        })

    return schedule
'''

# Example usage:
loan = 100000         # $600,000 mortgage
rate = 1            # 5% annual interest rate
term = 30             # 30-year mortgage
'''
# schedule = calculate_amortization_schedule(loan, rate, term)
'''
# Print the first 12 months
for entry in schedule[:360]:
    print(entry)

# Print summary
print(f"\nTotal payments: {len(schedule)} months")
print(f"Final balance: ${schedule[-1]['Balance']}")
'''
# Out:
# {'Month': 1, 'Payment': 321.64, 'Principal': 238.31, 'Interest': 83.33, 'Balance': 99761.69}
# {'Month': 2, 'Payment': 321.64, 'Principal': 238.5, 'Interest': 83.13, 'Balance': 99523.19}
# {'Month': 3, 'Payment': 321.64, 'Principal': 238.7, 'Interest': 82.94, 'Balance': 99284.49}
# {'Month': 4, 'Payment': 321.64, 'Principal': 238.9, 'Interest': 82.74, 'Balance': 99045.58}
# {'Month': 5, 'Payment': 321.64, 'Principal': 239.1, 'Interest': 82.54, 'Balance': 98806.48}
# {'Month': 6, 'Payment': 321.64, 'Principal': 239.3, 'Interest': 82.34, 'Balance': 98567.18}
# {'Month': 7, 'Payment': 321.64, 'Principal': 239.5, 'Interest': 82.14, 'Balance': 98327.68}
# {'Month': 8, 'Payment': 321.64, 'Principal': 239.7, 'Interest': 81.94, 'Balance': 98087.98}
# {'Month': 9, 'Payment': 321.64, 'Principal': 239.9, 'Interest': 81.74, 'Balance': 97848.08}
# {'Month': 10, 'Payment': 321.64, 'Principal': 240.1, 'Interest': 81.54, 'Balance': 97607.98}
# {'Month': 11, 'Payment': 321.64, 'Principal': 240.3, 'Interest': 81.34, 'Balance': 97367.68}
# {'Month': 12, 'Payment': 321.64, 'Principal': 240.5, 'Interest': 81.14, 'Balance': 97127.18}
# {'Month': 13, 'Payment': 321.64, 'Principal': 240.7, 'Interest': 80.94, 'Balance': 96886.48}
# {'Month': 14, 'Payment': 321.64, 'Principal': 240.9, 'Interest': 80.74, 'Balance': 96645.58}
# {'Month': 15, 'Payment': 321.64, 'Principal': 241.1, 'Interest': 80.54, 'Balance': 96404.48}
# {'Month': 16, 'Payment': 321.64, 'Principal': 241.3, 'Interest': 80.34, 'Balance': 96163.18}
# {'Month': 17, 'Payment': 321.64, 'Principal': 241.5, 'Interest': 80.14, 'Balance': 95921.67}
# {'Month': 18, 'Payment': 321.64, 'Principal': 241.7, 'Interest': 79.93, 'Balance': 95679.97}
# {'Month': 19, 'Payment': 321.64, 'Principal': 241.91, 'Interest': 79.73, 'Balance': 95438.06}
# {'Month': 20, 'Payment': 321.64, 'Principal': 242.11, 'Interest': 79.53, 'Balance': 95195.96}
# {'Month': 21, 'Payment': 321.64, 'Principal': 242.31, 'Interest': 79.33, 'Balance': 94953.65}
# {'Month': 22, 'Payment': 321.64, 'Principal': 242.51, 'Interest': 79.13, 'Balance': 94711.13}
# {'Month': 23, 'Payment': 321.64, 'Principal': 242.71, 'Interest': 78.93, 'Balance': 94468.42}
# {'Month': 24, 'Payment': 321.64, 'Principal': 242.92, 'Interest': 78.72, 'Balance': 94225.5}
# {'Month': 25, 'Payment': 321.64, 'Principal': 243.12, 'Interest': 78.52, 'Balance': 93982.39}
# {'Month': 26, 'Payment': 321.64, 'Principal': 243.32, 'Interest': 78.32, 'Balance': 93739.07}
# {'Month': 27, 'Payment': 321.64, 'Principal': 243.52, 'Interest': 78.12, 'Balance': 93495.54}
# {'Month': 28, 'Payment': 321.64, 'Principal': 243.73, 'Interest': 77.91, 'Balance': 93251.82}
# {'Month': 29, 'Payment': 321.64, 'Principal': 243.93, 'Interest': 77.71, 'Balance': 93007.89}
# {'Month': 30, 'Payment': 321.64, 'Principal': 244.13, 'Interest': 77.51, 'Balance': 92763.75}
# {'Month': 31, 'Payment': 321.64, 'Principal': 244.34, 'Interest': 77.3, 'Balance': 92519.42}
# {'Month': 32, 'Payment': 321.64, 'Principal': 244.54, 'Interest': 77.1, 'Balance': 92274.88}
# {'Month': 33, 'Payment': 321.64, 'Principal': 244.74, 'Interest': 76.9, 'Balance': 92030.13}
# {'Month': 34, 'Payment': 321.64, 'Principal': 244.95, 'Interest': 76.69, 'Balance': 91785.18}
# {'Month': 35, 'Payment': 321.64, 'Principal': 245.15, 'Interest': 76.49, 'Balance': 91540.03}
# {'Month': 36, 'Payment': 321.64, 'Principal': 245.36, 'Interest': 76.28, 'Balance': 91294.68}
# {'Month': 37, 'Payment': 321.64, 'Principal': 245.56, 'Interest': 76.08, 'Balance': 91049.12}
# {'Month': 38, 'Payment': 321.64, 'Principal': 245.77, 'Interest': 75.87, 'Balance': 90803.35}
# {'Month': 39, 'Payment': 321.64, 'Principal': 245.97, 'Interest': 75.67, 'Balance': 90557.38}
# {'Month': 40, 'Payment': 321.64, 'Principal': 246.18, 'Interest': 75.46, 'Balance': 90311.21}
# {'Month': 41, 'Payment': 321.64, 'Principal': 246.38, 'Interest': 75.26, 'Balance': 90064.83}
# {'Month': 42, 'Payment': 321.64, 'Principal': 246.59, 'Interest': 75.05, 'Balance': 89818.24}
# {'Month': 43, 'Payment': 321.64, 'Principal': 246.79, 'Interest': 74.85, 'Balance': 89571.45}
# {'Month': 44, 'Payment': 321.64, 'Principal': 247.0, 'Interest': 74.64, 'Balance': 89324.45}
# {'Month': 45, 'Payment': 321.64, 'Principal': 247.2, 'Interest': 74.44, 'Balance': 89077.25}
# {'Month': 46, 'Payment': 321.64, 'Principal': 247.41, 'Interest': 74.23, 'Balance': 88829.84}
# {'Month': 47, 'Payment': 321.64, 'Principal': 247.61, 'Interest': 74.02, 'Balance': 88582.23}
# {'Month': 48, 'Payment': 321.64, 'Principal': 247.82, 'Interest': 73.82, 'Balance': 88334.41}
# {'Month': 49, 'Payment': 321.64, 'Principal': 248.03, 'Interest': 73.61, 'Balance': 88086.38}
# {'Month': 50, 'Payment': 321.64, 'Principal': 248.23, 'Interest': 73.41, 'Balance': 87838.14}
# {'Month': 51, 'Payment': 321.64, 'Principal': 248.44, 'Interest': 73.2, 'Balance': 87589.7}
# {'Month': 52, 'Payment': 321.64, 'Principal': 248.65, 'Interest': 72.99, 'Balance': 87341.05}
# {'Month': 53, 'Payment': 321.64, 'Principal': 248.86, 'Interest': 72.78, 'Balance': 87092.2}
# {'Month': 54, 'Payment': 321.64, 'Principal': 249.06, 'Interest': 72.58, 'Balance': 86843.14}
# {'Month': 55, 'Payment': 321.64, 'Principal': 249.27, 'Interest': 72.37, 'Balance': 86593.87}
# {'Month': 56, 'Payment': 321.64, 'Principal': 249.48, 'Interest': 72.16, 'Balance': 86344.39}
# {'Month': 57, 'Payment': 321.64, 'Principal': 249.69, 'Interest': 71.95, 'Balance': 86094.7}
# {'Month': 58, 'Payment': 321.64, 'Principal': 249.89, 'Interest': 71.75, 'Balance': 85844.81}
# {'Month': 59, 'Payment': 321.64, 'Principal': 250.1, 'Interest': 71.54, 'Balance': 85594.71}
# {'Month': 60, 'Payment': 321.64, 'Principal': 250.31, 'Interest': 71.33, 'Balance': 85344.4}
# {'Month': 61, 'Payment': 321.64, 'Principal': 250.52, 'Interest': 71.12, 'Balance': 85093.88}
# {'Month': 62, 'Payment': 321.64, 'Principal': 250.73, 'Interest': 70.91, 'Balance': 84843.15}
# {'Month': 63, 'Payment': 321.64, 'Principal': 250.94, 'Interest': 70.7, 'Balance': 84592.21}
# {'Month': 64, 'Payment': 321.64, 'Principal': 251.15, 'Interest': 70.49, 'Balance': 84341.07}
# {'Month': 65, 'Payment': 321.64, 'Principal': 251.36, 'Interest': 70.28, 'Balance': 84089.71}
# {'Month': 66, 'Payment': 321.64, 'Principal': 251.56, 'Interest': 70.07, 'Balance': 83838.15}
# {'Month': 67, 'Payment': 321.64, 'Principal': 251.77, 'Interest': 69.87, 'Balance': 83586.37}
# {'Month': 68, 'Payment': 321.64, 'Principal': 251.98, 'Interest': 69.66, 'Balance': 83334.39}
# {'Month': 69, 'Payment': 321.64, 'Principal': 252.19, 'Interest': 69.45, 'Balance': 83082.19}
# {'Month': 70, 'Payment': 321.64, 'Principal': 252.4, 'Interest': 69.24, 'Balance': 82829.79}
# {'Month': 71, 'Payment': 321.64, 'Principal': 252.61, 'Interest': 69.02, 'Balance': 82577.17}
# {'Month': 72, 'Payment': 321.64, 'Principal': 252.83, 'Interest': 68.81, 'Balance': 82324.35}
# {'Month': 73, 'Payment': 321.64, 'Principal': 253.04, 'Interest': 68.6, 'Balance': 82071.31}
# {'Month': 74, 'Payment': 321.64, 'Principal': 253.25, 'Interest': 68.39, 'Balance': 81818.07}
# {'Month': 75, 'Payment': 321.64, 'Principal': 253.46, 'Interest': 68.18, 'Balance': 81564.61}
# {'Month': 76, 'Payment': 321.64, 'Principal': 253.67, 'Interest': 67.97, 'Balance': 81310.94}
# {'Month': 77, 'Payment': 321.64, 'Principal': 253.88, 'Interest': 67.76, 'Balance': 81057.06}
# {'Month': 78, 'Payment': 321.64, 'Principal': 254.09, 'Interest': 67.55, 'Balance': 80802.97}
# {'Month': 79, 'Payment': 321.64, 'Principal': 254.3, 'Interest': 67.34, 'Balance': 80548.66}
# {'Month': 80, 'Payment': 321.64, 'Principal': 254.52, 'Interest': 67.12, 'Balance': 80294.15}
# {'Month': 81, 'Payment': 321.64, 'Principal': 254.73, 'Interest': 66.91, 'Balance': 80039.42}
# {'Month': 82, 'Payment': 321.64, 'Principal': 254.94, 'Interest': 66.7, 'Balance': 79784.48}
# {'Month': 83, 'Payment': 321.64, 'Principal': 255.15, 'Interest': 66.49, 'Balance': 79529.33}
# {'Month': 84, 'Payment': 321.64, 'Principal': 255.37, 'Interest': 66.27, 'Balance': 79273.96}
# {'Month': 85, 'Payment': 321.64, 'Principal': 255.58, 'Interest': 66.06, 'Balance': 79018.38}
# {'Month': 86, 'Payment': 321.64, 'Principal': 255.79, 'Interest': 65.85, 'Balance': 78762.59}
# {'Month': 87, 'Payment': 321.64, 'Principal': 256.0, 'Interest': 65.64, 'Balance': 78506.59}
# {'Month': 88, 'Payment': 321.64, 'Principal': 256.22, 'Interest': 65.42, 'Balance': 78250.37}
# {'Month': 89, 'Payment': 321.64, 'Principal': 256.43, 'Interest': 65.21, 'Balance': 77993.94}
# {'Month': 90, 'Payment': 321.64, 'Principal': 256.64, 'Interest': 64.99, 'Balance': 77737.3}
# {'Month': 91, 'Payment': 321.64, 'Principal': 256.86, 'Interest': 64.78, 'Balance': 77480.44}
# {'Month': 92, 'Payment': 321.64, 'Principal': 257.07, 'Interest': 64.57, 'Balance': 77223.37}
# {'Month': 93, 'Payment': 321.64, 'Principal': 257.29, 'Interest': 64.35, 'Balance': 76966.08}
# {'Month': 94, 'Payment': 321.64, 'Principal': 257.5, 'Interest': 64.14, 'Balance': 76708.58}
# {'Month': 95, 'Payment': 321.64, 'Principal': 257.72, 'Interest': 63.92, 'Balance': 76450.86}
# {'Month': 96, 'Payment': 321.64, 'Principal': 257.93, 'Interest': 63.71, 'Balance': 76192.93}
# {'Month': 97, 'Payment': 321.64, 'Principal': 258.15, 'Interest': 63.49, 'Balance': 75934.79}
# {'Month': 98, 'Payment': 321.64, 'Principal': 258.36, 'Interest': 63.28, 'Balance': 75676.43}
# {'Month': 99, 'Payment': 321.64, 'Principal': 258.58, 'Interest': 63.06, 'Balance': 75417.85}
# {'Month': 100, 'Payment': 321.64, 'Principal': 258.79, 'Interest': 62.85, 'Balance': 75159.06}
# {'Month': 101, 'Payment': 321.64, 'Principal': 259.01, 'Interest': 62.63, 'Balance': 74900.05}
# {'Month': 102, 'Payment': 321.64, 'Principal': 259.22, 'Interest': 62.42, 'Balance': 74640.83}
# {'Month': 103, 'Payment': 321.64, 'Principal': 259.44, 'Interest': 62.2, 'Balance': 74381.39}
# {'Month': 104, 'Payment': 321.64, 'Principal': 259.66, 'Interest': 61.98, 'Balance': 74121.74}
# {'Month': 105, 'Payment': 321.64, 'Principal': 259.87, 'Interest': 61.77, 'Balance': 73861.86}
# {'Month': 106, 'Payment': 321.64, 'Principal': 260.09, 'Interest': 61.55, 'Balance': 73601.78}
# {'Month': 107, 'Payment': 321.64, 'Principal': 260.3, 'Interest': 61.33, 'Balance': 73341.47}
# {'Month': 108, 'Payment': 321.64, 'Principal': 260.52, 'Interest': 61.12, 'Balance': 73080.95}
# {'Month': 109, 'Payment': 321.64, 'Principal': 260.74, 'Interest': 60.9, 'Balance': 72820.21}
# {'Month': 110, 'Payment': 321.64, 'Principal': 260.96, 'Interest': 60.68, 'Balance': 72559.25}
# {'Month': 111, 'Payment': 321.64, 'Principal': 261.17, 'Interest': 60.47, 'Balance': 72298.08}
# {'Month': 112, 'Payment': 321.64, 'Principal': 261.39, 'Interest': 60.25, 'Balance': 72036.69}
# {'Month': 113, 'Payment': 321.64, 'Principal': 261.61, 'Interest': 60.03, 'Balance': 71775.08}
# {'Month': 114, 'Payment': 321.64, 'Principal': 261.83, 'Interest': 59.81, 'Balance': 71513.25}
# {'Month': 115, 'Payment': 321.64, 'Principal': 262.05, 'Interest': 59.59, 'Balance': 71251.21}
# {'Month': 116, 'Payment': 321.64, 'Principal': 262.26, 'Interest': 59.38, 'Balance': 70988.95}
# {'Month': 117, 'Payment': 321.64, 'Principal': 262.48, 'Interest': 59.16, 'Balance': 70726.46}
# {'Month': 118, 'Payment': 321.64, 'Principal': 262.7, 'Interest': 58.94, 'Balance': 70463.76}
# {'Month': 119, 'Payment': 321.64, 'Principal': 262.92, 'Interest': 58.72, 'Balance': 70200.84}
# {'Month': 120, 'Payment': 321.64, 'Principal': 263.14, 'Interest': 58.5, 'Balance': 69937.7}
# {'Month': 121, 'Payment': 321.64, 'Principal': 263.36, 'Interest': 58.28, 'Balance': 69674.35}
# {'Month': 122, 'Payment': 321.64, 'Principal': 263.58, 'Interest': 58.06, 'Balance': 69410.77}
# {'Month': 123, 'Payment': 321.64, 'Principal': 263.8, 'Interest': 57.84, 'Balance': 69146.97}
# {'Month': 124, 'Payment': 321.64, 'Principal': 264.02, 'Interest': 57.62, 'Balance': 68882.95}
# {'Month': 125, 'Payment': 321.64, 'Principal': 264.24, 'Interest': 57.4, 'Balance': 68618.72}
# {'Month': 126, 'Payment': 321.64, 'Principal': 264.46, 'Interest': 57.18, 'Balance': 68354.26}
# {'Month': 127, 'Payment': 321.64, 'Principal': 264.68, 'Interest': 56.96, 'Balance': 68089.58}
# {'Month': 128, 'Payment': 321.64, 'Principal': 264.9, 'Interest': 56.74, 'Balance': 67824.68}
# {'Month': 129, 'Payment': 321.64, 'Principal': 265.12, 'Interest': 56.52, 'Balance': 67559.57}
# {'Month': 130, 'Payment': 321.64, 'Principal': 265.34, 'Interest': 56.3, 'Balance': 67294.23}
# {'Month': 131, 'Payment': 321.64, 'Principal': 265.56, 'Interest': 56.08, 'Balance': 67028.66}
# {'Month': 132, 'Payment': 321.64, 'Principal': 265.78, 'Interest': 55.86, 'Balance': 66762.88}
# {'Month': 133, 'Payment': 321.64, 'Principal': 266.0, 'Interest': 55.64, 'Balance': 66496.88}
# {'Month': 134, 'Payment': 321.64, 'Principal': 266.23, 'Interest': 55.41, 'Balance': 66230.65}
# {'Month': 135, 'Payment': 321.64, 'Principal': 266.45, 'Interest': 55.19, 'Balance': 65964.21}
# {'Month': 136, 'Payment': 321.64, 'Principal': 266.67, 'Interest': 54.97, 'Balance': 65697.54}
# {'Month': 137, 'Payment': 321.64, 'Principal': 266.89, 'Interest': 54.75, 'Balance': 65430.64}
# {'Month': 138, 'Payment': 321.64, 'Principal': 267.11, 'Interest': 54.53, 'Balance': 65163.53}
# {'Month': 139, 'Payment': 321.64, 'Principal': 267.34, 'Interest': 54.3, 'Balance': 64896.19}
# {'Month': 140, 'Payment': 321.64, 'Principal': 267.56, 'Interest': 54.08, 'Balance': 64628.63}
# {'Month': 141, 'Payment': 321.64, 'Principal': 267.78, 'Interest': 53.86, 'Balance': 64360.85}
# {'Month': 142, 'Payment': 321.64, 'Principal': 268.01, 'Interest': 53.63, 'Balance': 64092.85}
# {'Month': 143, 'Payment': 321.64, 'Principal': 268.23, 'Interest': 53.41, 'Balance': 63824.62}
# {'Month': 144, 'Payment': 321.64, 'Principal': 268.45, 'Interest': 53.19, 'Balance': 63556.17}
# {'Month': 145, 'Payment': 321.64, 'Principal': 268.68, 'Interest': 52.96, 'Balance': 63287.49}
# {'Month': 146, 'Payment': 321.64, 'Principal': 268.9, 'Interest': 52.74, 'Balance': 63018.59}
# {'Month': 147, 'Payment': 321.64, 'Principal': 269.12, 'Interest': 52.52, 'Balance': 62749.47}
# {'Month': 148, 'Payment': 321.64, 'Principal': 269.35, 'Interest': 52.29, 'Balance': 62480.12}
# {'Month': 149, 'Payment': 321.64, 'Principal': 269.57, 'Interest': 52.07, 'Balance': 62210.54}
# {'Month': 150, 'Payment': 321.64, 'Principal': 269.8, 'Interest': 51.84, 'Balance': 61940.75}
# {'Month': 151, 'Payment': 321.64, 'Principal': 270.02, 'Interest': 51.62, 'Balance': 61670.73}
# {'Month': 152, 'Payment': 321.64, 'Principal': 270.25, 'Interest': 51.39, 'Balance': 61400.48}
# {'Month': 153, 'Payment': 321.64, 'Principal': 270.47, 'Interest': 51.17, 'Balance': 61130.01}
# {'Month': 154, 'Payment': 321.64, 'Principal': 270.7, 'Interest': 50.94, 'Balance': 60859.31}
# {'Month': 155, 'Payment': 321.64, 'Principal': 270.92, 'Interest': 50.72, 'Balance': 60588.38}
# {'Month': 156, 'Payment': 321.64, 'Principal': 271.15, 'Interest': 50.49, 'Balance': 60317.23}
# {'Month': 157, 'Payment': 321.64, 'Principal': 271.38, 'Interest': 50.26, 'Balance': 60045.86}
# {'Month': 158, 'Payment': 321.64, 'Principal': 271.6, 'Interest': 50.04, 'Balance': 59774.26}
# {'Month': 159, 'Payment': 321.64, 'Principal': 271.83, 'Interest': 49.81, 'Balance': 59502.43}
# {'Month': 160, 'Payment': 321.64, 'Principal': 272.05, 'Interest': 49.59, 'Balance': 59230.38}
# {'Month': 161, 'Payment': 321.64, 'Principal': 272.28, 'Interest': 49.36, 'Balance': 58958.1}
# {'Month': 162, 'Payment': 321.64, 'Principal': 272.51, 'Interest': 49.13, 'Balance': 58685.59}
# {'Month': 163, 'Payment': 321.64, 'Principal': 272.73, 'Interest': 48.9, 'Balance': 58412.85}
# {'Month': 164, 'Payment': 321.64, 'Principal': 272.96, 'Interest': 48.68, 'Balance': 58139.89}
# {'Month': 165, 'Payment': 321.64, 'Principal': 273.19, 'Interest': 48.45, 'Balance': 57866.7}
# {'Month': 166, 'Payment': 321.64, 'Principal': 273.42, 'Interest': 48.22, 'Balance': 57593.28}
# {'Month': 167, 'Payment': 321.64, 'Principal': 273.65, 'Interest': 47.99, 'Balance': 57319.64}
# {'Month': 168, 'Payment': 321.64, 'Principal': 273.87, 'Interest': 47.77, 'Balance': 57045.77}
# {'Month': 169, 'Payment': 321.64, 'Principal': 274.1, 'Interest': 47.54, 'Balance': 56771.66}
# {'Month': 170, 'Payment': 321.64, 'Principal': 274.33, 'Interest': 47.31, 'Balance': 56497.33}
# {'Month': 171, 'Payment': 321.64, 'Principal': 274.56, 'Interest': 47.08, 'Balance': 56222.78}
# {'Month': 172, 'Payment': 321.64, 'Principal': 274.79, 'Interest': 46.85, 'Balance': 55947.99}
# {'Month': 173, 'Payment': 321.64, 'Principal': 275.02, 'Interest': 46.62, 'Balance': 55672.97}
# {'Month': 174, 'Payment': 321.64, 'Principal': 275.25, 'Interest': 46.39, 'Balance': 55397.73}
# {'Month': 175, 'Payment': 321.64, 'Principal': 275.47, 'Interest': 46.16, 'Balance': 55122.25}
# {'Month': 176, 'Payment': 321.64, 'Principal': 275.7, 'Interest': 45.94, 'Balance': 54846.55}
# {'Month': 177, 'Payment': 321.64, 'Principal': 275.93, 'Interest': 45.71, 'Balance': 54570.61}
# {'Month': 178, 'Payment': 321.64, 'Principal': 276.16, 'Interest': 45.48, 'Balance': 54294.45}
# {'Month': 179, 'Payment': 321.64, 'Principal': 276.39, 'Interest': 45.25, 'Balance': 54018.06}
# {'Month': 180, 'Payment': 321.64, 'Principal': 276.62, 'Interest': 45.02, 'Balance': 53741.43}
# {'Month': 181, 'Payment': 321.64, 'Principal': 276.85, 'Interest': 44.78, 'Balance': 53464.58}
# {'Month': 182, 'Payment': 321.64, 'Principal': 277.09, 'Interest': 44.55, 'Balance': 53187.49}
# {'Month': 183, 'Payment': 321.64, 'Principal': 277.32, 'Interest': 44.32, 'Balance': 52910.17}
# {'Month': 184, 'Payment': 321.64, 'Principal': 277.55, 'Interest': 44.09, 'Balance': 52632.63}
# {'Month': 185, 'Payment': 321.64, 'Principal': 277.78, 'Interest': 43.86, 'Balance': 52354.85}
# {'Month': 186, 'Payment': 321.64, 'Principal': 278.01, 'Interest': 43.63, 'Balance': 52076.84}
# {'Month': 187, 'Payment': 321.64, 'Principal': 278.24, 'Interest': 43.4, 'Balance': 51798.59}
# {'Month': 188, 'Payment': 321.64, 'Principal': 278.47, 'Interest': 43.17, 'Balance': 51520.12}
# {'Month': 189, 'Payment': 321.64, 'Principal': 278.71, 'Interest': 42.93, 'Balance': 51241.41}
# {'Month': 190, 'Payment': 321.64, 'Principal': 278.94, 'Interest': 42.7, 'Balance': 50962.48}
# {'Month': 191, 'Payment': 321.64, 'Principal': 279.17, 'Interest': 42.47, 'Balance': 50683.31}
# {'Month': 192, 'Payment': 321.64, 'Principal': 279.4, 'Interest': 42.24, 'Balance': 50403.9}
# {'Month': 193, 'Payment': 321.64, 'Principal': 279.64, 'Interest': 42.0, 'Balance': 50124.27}
# {'Month': 194, 'Payment': 321.64, 'Principal': 279.87, 'Interest': 41.77, 'Balance': 49844.4}
# {'Month': 195, 'Payment': 321.64, 'Principal': 280.1, 'Interest': 41.54, 'Balance': 49564.29}
# {'Month': 196, 'Payment': 321.64, 'Principal': 280.34, 'Interest': 41.3, 'Balance': 49283.96}
# {'Month': 197, 'Payment': 321.64, 'Principal': 280.57, 'Interest': 41.07, 'Balance': 49003.39}
# {'Month': 198, 'Payment': 321.64, 'Principal': 280.8, 'Interest': 40.84, 'Balance': 48722.59}
# {'Month': 199, 'Payment': 321.64, 'Principal': 281.04, 'Interest': 40.6, 'Balance': 48441.55}
# {'Month': 200, 'Payment': 321.64, 'Principal': 281.27, 'Interest': 40.37, 'Balance': 48160.28}
# {'Month': 201, 'Payment': 321.64, 'Principal': 281.51, 'Interest': 40.13, 'Balance': 47878.77}
# {'Month': 202, 'Payment': 321.64, 'Principal': 281.74, 'Interest': 39.9, 'Balance': 47597.03}
# {'Month': 203, 'Payment': 321.64, 'Principal': 281.98, 'Interest': 39.66, 'Balance': 47315.05}
# {'Month': 204, 'Payment': 321.64, 'Principal': 282.21, 'Interest': 39.43, 'Balance': 47032.84}
# {'Month': 205, 'Payment': 321.64, 'Principal': 282.45, 'Interest': 39.19, 'Balance': 46750.4}
# {'Month': 206, 'Payment': 321.64, 'Principal': 282.68, 'Interest': 38.96, 'Balance': 46467.72}
# {'Month': 207, 'Payment': 321.64, 'Principal': 282.92, 'Interest': 38.72, 'Balance': 46184.8}
# {'Month': 208, 'Payment': 321.64, 'Principal': 283.15, 'Interest': 38.49, 'Balance': 45901.65}
# {'Month': 209, 'Payment': 321.64, 'Principal': 283.39, 'Interest': 38.25, 'Balance': 45618.26}
# {'Month': 210, 'Payment': 321.64, 'Principal': 283.62, 'Interest': 38.02, 'Balance': 45334.64}
# {'Month': 211, 'Payment': 321.64, 'Principal': 283.86, 'Interest': 37.78, 'Balance': 45050.78}
# {'Month': 212, 'Payment': 321.64, 'Principal': 284.1, 'Interest': 37.54, 'Balance': 44766.68}
# {'Month': 213, 'Payment': 321.64, 'Principal': 284.33, 'Interest': 37.31, 'Balance': 44482.35}
# {'Month': 214, 'Payment': 321.64, 'Principal': 284.57, 'Interest': 37.07, 'Balance': 44197.77}
# {'Month': 215, 'Payment': 321.64, 'Principal': 284.81, 'Interest': 36.83, 'Balance': 43912.97}
# {'Month': 216, 'Payment': 321.64, 'Principal': 285.05, 'Interest': 36.59, 'Balance': 43627.92}
# {'Month': 217, 'Payment': 321.64, 'Principal': 285.28, 'Interest': 36.36, 'Balance': 43342.64}
# {'Month': 218, 'Payment': 321.64, 'Principal': 285.52, 'Interest': 36.12, 'Balance': 43057.12}
# {'Month': 219, 'Payment': 321.64, 'Principal': 285.76, 'Interest': 35.88, 'Balance': 42771.36}
# {'Month': 220, 'Payment': 321.64, 'Principal': 286.0, 'Interest': 35.64, 'Balance': 42485.36}
# {'Month': 221, 'Payment': 321.64, 'Principal': 286.24, 'Interest': 35.4, 'Balance': 42199.13}
# {'Month': 222, 'Payment': 321.64, 'Principal': 286.47, 'Interest': 35.17, 'Balance': 41912.65}
# {'Month': 223, 'Payment': 321.64, 'Principal': 286.71, 'Interest': 34.93, 'Balance': 41625.94}
# {'Month': 224, 'Payment': 321.64, 'Principal': 286.95, 'Interest': 34.69, 'Balance': 41338.99}
# {'Month': 225, 'Payment': 321.64, 'Principal': 287.19, 'Interest': 34.45, 'Balance': 41051.8}
# {'Month': 226, 'Payment': 321.64, 'Principal': 287.43, 'Interest': 34.21, 'Balance': 40764.37}
# {'Month': 227, 'Payment': 321.64, 'Principal': 287.67, 'Interest': 33.97, 'Balance': 40476.7}
# {'Month': 228, 'Payment': 321.64, 'Principal': 287.91, 'Interest': 33.73, 'Balance': 40188.79}
# {'Month': 229, 'Payment': 321.64, 'Principal': 288.15, 'Interest': 33.49, 'Balance': 39900.64}
# {'Month': 230, 'Payment': 321.64, 'Principal': 288.39, 'Interest': 33.25, 'Balance': 39612.25}
# {'Month': 231, 'Payment': 321.64, 'Principal': 288.63, 'Interest': 33.01, 'Balance': 39323.62}
# {'Month': 232, 'Payment': 321.64, 'Principal': 288.87, 'Interest': 32.77, 'Balance': 39034.75}
# {'Month': 233, 'Payment': 321.64, 'Principal': 289.11, 'Interest': 32.53, 'Balance': 38745.64}
# {'Month': 234, 'Payment': 321.64, 'Principal': 289.35, 'Interest': 32.29, 'Balance': 38456.29}
# {'Month': 235, 'Payment': 321.64, 'Principal': 289.59, 'Interest': 32.05, 'Balance': 38166.7}
# {'Month': 236, 'Payment': 321.64, 'Principal': 289.83, 'Interest': 31.81, 'Balance': 37876.87}
# {'Month': 237, 'Payment': 321.64, 'Principal': 290.08, 'Interest': 31.56, 'Balance': 37586.79}
# {'Month': 238, 'Payment': 321.64, 'Principal': 290.32, 'Interest': 31.32, 'Balance': 37296.47}
# {'Month': 239, 'Payment': 321.64, 'Principal': 290.56, 'Interest': 31.08, 'Balance': 37005.91}
# {'Month': 240, 'Payment': 321.64, 'Principal': 290.8, 'Interest': 30.84, 'Balance': 36715.11}
# {'Month': 241, 'Payment': 321.64, 'Principal': 291.04, 'Interest': 30.6, 'Balance': 36424.07}
# {'Month': 242, 'Payment': 321.64, 'Principal': 291.29, 'Interest': 30.35, 'Balance': 36132.78}
# {'Month': 243, 'Payment': 321.64, 'Principal': 291.53, 'Interest': 30.11, 'Balance': 35841.25}
# {'Month': 244, 'Payment': 321.64, 'Principal': 291.77, 'Interest': 29.87, 'Balance': 35549.48}
# {'Month': 245, 'Payment': 321.64, 'Principal': 292.01, 'Interest': 29.62, 'Balance': 35257.47}
# {'Month': 246, 'Payment': 321.64, 'Principal': 292.26, 'Interest': 29.38, 'Balance': 34965.21}
# {'Month': 247, 'Payment': 321.64, 'Principal': 292.5, 'Interest': 29.14, 'Balance': 34672.71}
# {'Month': 248, 'Payment': 321.64, 'Principal': 292.75, 'Interest': 28.89, 'Balance': 34379.96}
# {'Month': 249, 'Payment': 321.64, 'Principal': 292.99, 'Interest': 28.65, 'Balance': 34086.97}
# {'Month': 250, 'Payment': 321.64, 'Principal': 293.23, 'Interest': 28.41, 'Balance': 33793.74}
# {'Month': 251, 'Payment': 321.64, 'Principal': 293.48, 'Interest': 28.16, 'Balance': 33500.26}
# {'Month': 252, 'Payment': 321.64, 'Principal': 293.72, 'Interest': 27.92, 'Balance': 33206.54}
# {'Month': 253, 'Payment': 321.64, 'Principal': 293.97, 'Interest': 27.67, 'Balance': 32912.57}
# {'Month': 254, 'Payment': 321.64, 'Principal': 294.21, 'Interest': 27.43, 'Balance': 32618.36}
# {'Month': 255, 'Payment': 321.64, 'Principal': 294.46, 'Interest': 27.18, 'Balance': 32323.9}
# {'Month': 256, 'Payment': 321.64, 'Principal': 294.7, 'Interest': 26.94, 'Balance': 32029.2}
# {'Month': 257, 'Payment': 321.64, 'Principal': 294.95, 'Interest': 26.69, 'Balance': 31734.25}
# {'Month': 258, 'Payment': 321.64, 'Principal': 295.19, 'Interest': 26.45, 'Balance': 31439.05}
# {'Month': 259, 'Payment': 321.64, 'Principal': 295.44, 'Interest': 26.2, 'Balance': 31143.61}
# {'Month': 260, 'Payment': 321.64, 'Principal': 295.69, 'Interest': 25.95, 'Balance': 30847.93}
# {'Month': 261, 'Payment': 321.64, 'Principal': 295.93, 'Interest': 25.71, 'Balance': 30551.99}
# {'Month': 262, 'Payment': 321.64, 'Principal': 296.18, 'Interest': 25.46, 'Balance': 30255.82}
# {'Month': 263, 'Payment': 321.64, 'Principal': 296.43, 'Interest': 25.21, 'Balance': 29959.39}
# {'Month': 264, 'Payment': 321.64, 'Principal': 296.67, 'Interest': 24.97, 'Balance': 29662.72}
# {'Month': 265, 'Payment': 321.64, 'Principal': 296.92, 'Interest': 24.72, 'Balance': 29365.8}
# {'Month': 266, 'Payment': 321.64, 'Principal': 297.17, 'Interest': 24.47, 'Balance': 29068.63}
# {'Month': 267, 'Payment': 321.64, 'Principal': 297.42, 'Interest': 24.22, 'Balance': 28771.21}
# {'Month': 268, 'Payment': 321.64, 'Principal': 297.66, 'Interest': 23.98, 'Balance': 28473.55}
# {'Month': 269, 'Payment': 321.64, 'Principal': 297.91, 'Interest': 23.73, 'Balance': 28175.64}
# {'Month': 270, 'Payment': 321.64, 'Principal': 298.16, 'Interest': 23.48, 'Balance': 27877.48}
# {'Month': 271, 'Payment': 321.64, 'Principal': 298.41, 'Interest': 23.23, 'Balance': 27579.07}
# {'Month': 272, 'Payment': 321.64, 'Principal': 298.66, 'Interest': 22.98, 'Balance': 27280.41}
# {'Month': 273, 'Payment': 321.64, 'Principal': 298.91, 'Interest': 22.73, 'Balance': 26981.51}
# {'Month': 274, 'Payment': 321.64, 'Principal': 299.15, 'Interest': 22.48, 'Balance': 26682.35}
# {'Month': 275, 'Payment': 321.64, 'Principal': 299.4, 'Interest': 22.24, 'Balance': 26382.95}
# {'Month': 276, 'Payment': 321.64, 'Principal': 299.65, 'Interest': 21.99, 'Balance': 26083.29}
# {'Month': 277, 'Payment': 321.64, 'Principal': 299.9, 'Interest': 21.74, 'Balance': 25783.39}
# {'Month': 278, 'Payment': 321.64, 'Principal': 300.15, 'Interest': 21.49, 'Balance': 25483.24}
# {'Month': 279, 'Payment': 321.64, 'Principal': 300.4, 'Interest': 21.24, 'Balance': 25182.83}
# {'Month': 280, 'Payment': 321.64, 'Principal': 300.65, 'Interest': 20.99, 'Balance': 24882.18}
# {'Month': 281, 'Payment': 321.64, 'Principal': 300.9, 'Interest': 20.74, 'Balance': 24581.27}
# {'Month': 282, 'Payment': 321.64, 'Principal': 301.16, 'Interest': 20.48, 'Balance': 24280.12}
# {'Month': 283, 'Payment': 321.64, 'Principal': 301.41, 'Interest': 20.23, 'Balance': 23978.71}
# {'Month': 284, 'Payment': 321.64, 'Principal': 301.66, 'Interest': 19.98, 'Balance': 23677.06}
# {'Month': 285, 'Payment': 321.64, 'Principal': 301.91, 'Interest': 19.73, 'Balance': 23375.15}
# {'Month': 286, 'Payment': 321.64, 'Principal': 302.16, 'Interest': 19.48, 'Balance': 23072.99}
# {'Month': 287, 'Payment': 321.64, 'Principal': 302.41, 'Interest': 19.23, 'Balance': 22770.57}
# {'Month': 288, 'Payment': 321.64, 'Principal': 302.66, 'Interest': 18.98, 'Balance': 22467.91}
# {'Month': 289, 'Payment': 321.64, 'Principal': 302.92, 'Interest': 18.72, 'Balance': 22164.99}
# {'Month': 290, 'Payment': 321.64, 'Principal': 303.17, 'Interest': 18.47, 'Balance': 21861.83}
# {'Month': 291, 'Payment': 321.64, 'Principal': 303.42, 'Interest': 18.22, 'Balance': 21558.4}
# {'Month': 292, 'Payment': 321.64, 'Principal': 303.67, 'Interest': 17.97, 'Balance': 21254.73}
# {'Month': 293, 'Payment': 321.64, 'Principal': 303.93, 'Interest': 17.71, 'Balance': 20950.8}
# {'Month': 294, 'Payment': 321.64, 'Principal': 304.18, 'Interest': 17.46, 'Balance': 20646.62}
# {'Month': 295, 'Payment': 321.64, 'Principal': 304.43, 'Interest': 17.21, 'Balance': 20342.19}
# {'Month': 296, 'Payment': 321.64, 'Principal': 304.69, 'Interest': 16.95, 'Balance': 20037.5}
# {'Month': 297, 'Payment': 321.64, 'Principal': 304.94, 'Interest': 16.7, 'Balance': 19732.56}
# {'Month': 298, 'Payment': 321.64, 'Principal': 305.2, 'Interest': 16.44, 'Balance': 19427.36}
# {'Month': 299, 'Payment': 321.64, 'Principal': 305.45, 'Interest': 16.19, 'Balance': 19121.91}
# {'Month': 300, 'Payment': 321.64, 'Principal': 305.7, 'Interest': 15.93, 'Balance': 18816.21}
# {'Month': 301, 'Payment': 321.64, 'Principal': 305.96, 'Interest': 15.68, 'Balance': 18510.25}
# {'Month': 302, 'Payment': 321.64, 'Principal': 306.21, 'Interest': 15.43, 'Balance': 18204.04}
# {'Month': 303, 'Payment': 321.64, 'Principal': 306.47, 'Interest': 15.17, 'Balance': 17897.57}
# {'Month': 304, 'Payment': 321.64, 'Principal': 306.72, 'Interest': 14.91, 'Balance': 17590.84}
# {'Month': 305, 'Payment': 321.64, 'Principal': 306.98, 'Interest': 14.66, 'Balance': 17283.86}
# {'Month': 306, 'Payment': 321.64, 'Principal': 307.24, 'Interest': 14.4, 'Balance': 16976.62}
# {'Month': 307, 'Payment': 321.64, 'Principal': 307.49, 'Interest': 14.15, 'Balance': 16669.13}
# {'Month': 308, 'Payment': 321.64, 'Principal': 307.75, 'Interest': 13.89, 'Balance': 16361.38}
# {'Month': 309, 'Payment': 321.64, 'Principal': 308.01, 'Interest': 13.63, 'Balance': 16053.38}
# {'Month': 310, 'Payment': 321.64, 'Principal': 308.26, 'Interest': 13.38, 'Balance': 15745.12}
# {'Month': 311, 'Payment': 321.64, 'Principal': 308.52, 'Interest': 13.12, 'Balance': 15436.6}
# {'Month': 312, 'Payment': 321.64, 'Principal': 308.78, 'Interest': 12.86, 'Balance': 15127.82}
# {'Month': 313, 'Payment': 321.64, 'Principal': 309.03, 'Interest': 12.61, 'Balance': 14818.79}
# {'Month': 314, 'Payment': 321.64, 'Principal': 309.29, 'Interest': 12.35, 'Balance': 14509.5}
# {'Month': 315, 'Payment': 321.64, 'Principal': 309.55, 'Interest': 12.09, 'Balance': 14199.95}
# {'Month': 316, 'Payment': 321.64, 'Principal': 309.81, 'Interest': 11.83, 'Balance': 13890.14}
# {'Month': 317, 'Payment': 321.64, 'Principal': 310.06, 'Interest': 11.58, 'Balance': 13580.08}
# {'Month': 318, 'Payment': 321.64, 'Principal': 310.32, 'Interest': 11.32, 'Balance': 13269.76}
# {'Month': 319, 'Payment': 321.64, 'Principal': 310.58, 'Interest': 11.06, 'Balance': 12959.18}
# {'Month': 320, 'Payment': 321.64, 'Principal': 310.84, 'Interest': 10.8, 'Balance': 12648.34}
# {'Month': 321, 'Payment': 321.64, 'Principal': 311.1, 'Interest': 10.54, 'Balance': 12337.24}
# {'Month': 322, 'Payment': 321.64, 'Principal': 311.36, 'Interest': 10.28, 'Balance': 12025.88}
# {'Month': 323, 'Payment': 321.64, 'Principal': 311.62, 'Interest': 10.02, 'Balance': 11714.26}
# {'Month': 324, 'Payment': 321.64, 'Principal': 311.88, 'Interest': 9.76, 'Balance': 11402.38}
# {'Month': 325, 'Payment': 321.64, 'Principal': 312.14, 'Interest': 9.5, 'Balance': 11090.24}
# {'Month': 326, 'Payment': 321.64, 'Principal': 312.4, 'Interest': 9.24, 'Balance': 10777.85}
# {'Month': 327, 'Payment': 321.64, 'Principal': 312.66, 'Interest': 8.98, 'Balance': 10465.19}
# {'Month': 328, 'Payment': 321.64, 'Principal': 312.92, 'Interest': 8.72, 'Balance': 10152.27}
# {'Month': 329, 'Payment': 321.64, 'Principal': 313.18, 'Interest': 8.46, 'Balance': 9839.09}
# {'Month': 330, 'Payment': 321.64, 'Principal': 313.44, 'Interest': 8.2, 'Balance': 9525.65}
# {'Month': 331, 'Payment': 321.64, 'Principal': 313.7, 'Interest': 7.94, 'Balance': 9211.95}
# {'Month': 332, 'Payment': 321.64, 'Principal': 313.96, 'Interest': 7.68, 'Balance': 8897.99}
# {'Month': 333, 'Payment': 321.64, 'Principal': 314.22, 'Interest': 7.41, 'Balance': 8583.76}
# {'Month': 334, 'Payment': 321.64, 'Principal': 314.49, 'Interest': 7.15, 'Balance': 8269.28}
# {'Month': 335, 'Payment': 321.64, 'Principal': 314.75, 'Interest': 6.89, 'Balance': 7954.53}
# {'Month': 336, 'Payment': 321.64, 'Principal': 315.01, 'Interest': 6.63, 'Balance': 7639.52}
# {'Month': 337, 'Payment': 321.64, 'Principal': 315.27, 'Interest': 6.37, 'Balance': 7324.24}
# {'Month': 338, 'Payment': 321.64, 'Principal': 315.54, 'Interest': 6.1, 'Balance': 7008.71}
# {'Month': 339, 'Payment': 321.64, 'Principal': 315.8, 'Interest': 5.84, 'Balance': 6692.91}
# {'Month': 340, 'Payment': 321.64, 'Principal': 316.06, 'Interest': 5.58, 'Balance': 6376.85}
# {'Month': 341, 'Payment': 321.64, 'Principal': 316.33, 'Interest': 5.31, 'Balance': 6060.52}
# {'Month': 342, 'Payment': 321.64, 'Principal': 316.59, 'Interest': 5.05, 'Balance': 5743.93}
# {'Month': 343, 'Payment': 321.64, 'Principal': 316.85, 'Interest': 4.79, 'Balance': 5427.08}
# {'Month': 344, 'Payment': 321.64, 'Principal': 317.12, 'Interest': 4.52, 'Balance': 5109.96}
# {'Month': 345, 'Payment': 321.64, 'Principal': 317.38, 'Interest': 4.26, 'Balance': 4792.58}
# {'Month': 346, 'Payment': 321.64, 'Principal': 317.65, 'Interest': 3.99, 'Balance': 4474.93}
# {'Month': 347, 'Payment': 321.64, 'Principal': 317.91, 'Interest': 3.73, 'Balance': 4157.02}
# {'Month': 348, 'Payment': 321.64, 'Principal': 318.18, 'Interest': 3.46, 'Balance': 3838.85}
# {'Month': 349, 'Payment': 321.64, 'Principal': 318.44, 'Interest': 3.2, 'Balance': 3520.41}
# {'Month': 350, 'Payment': 321.64, 'Principal': 318.71, 'Interest': 2.93, 'Balance': 3201.7}
# {'Month': 351, 'Payment': 321.64, 'Principal': 318.97, 'Interest': 2.67, 'Balance': 2882.73}
# {'Month': 352, 'Payment': 321.64, 'Principal': 319.24, 'Interest': 2.4, 'Balance': 2563.49}
# {'Month': 353, 'Payment': 321.64, 'Principal': 319.5, 'Interest': 2.14, 'Balance': 2243.99}
# {'Month': 354, 'Payment': 321.64, 'Principal': 319.77, 'Interest': 1.87, 'Balance': 1924.22}
# {'Month': 355, 'Payment': 321.64, 'Principal': 320.04, 'Interest': 1.6, 'Balance': 1604.18}
# {'Month': 356, 'Payment': 321.64, 'Principal': 320.3, 'Interest': 1.34, 'Balance': 1283.88}
# {'Month': 357, 'Payment': 321.64, 'Principal': 320.57, 'Interest': 1.07, 'Balance': 963.31}
# {'Month': 358, 'Payment': 321.64, 'Principal': 320.84, 'Interest': 0.8, 'Balance': 642.48}
# {'Month': 359, 'Payment': 321.64, 'Principal': 321.1, 'Interest': 0.54, 'Balance': 321.37}
# {'Month': 360, 'Payment': 321.64, 'Principal': 321.37, 'Interest': 0.27, 'Balance': 0}
#
# Total payments: 360 months
# Final balance: $0

# %%
schedule["Payment"][1]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 schedule["Payment"][1]
#
# NameError: name 'schedule' is not defined

# %%
#def calc_growth(price,pctAnnualGrowth,y):
 #   growth=pctAnnualGrowth*price*y
  #  return growth

# %%
x in schedule["Month"]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[332], line 1
# ----> 1 x in schedule["Month"]
#
# NameError: name 'x' is not defined
